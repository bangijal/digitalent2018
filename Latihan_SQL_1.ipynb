# %% [markdown]
# # Latihan SQL_1

# %% [markdown]
# Nama : Rizal Imran Rusyadi (kelas : BD-B)

# %% [markdown]
# #### Load (koneksi database)

# %%
import pymysql
import pandas as pd

host = '127.0.0.1'
port = "3306"
user = 'root'
password = ''
database = 'classicmodels'

conn = pymysql.connect(
    host=host,
    port=int(port),
    user=user,
    passwd=password,
    db=database,
    charset='utf8mb4')

def run(sql):
    df = pd.read_sql_query(sql,conn)
    return df

# %%
# Menampilkan seluruh tabel yang dimiliki database classicmodels

run("SHOW TABLES")
# Out:
#   Tables_in_classicmodels
# 0               customers
# 1               employees
# 2                 offices
# 3            orderdetails
# 4                  orders
# 5                payments
# 6            productlines
# 7                products

# %% [markdown]
# ### 1. Prepare a list of offices sorted by country, state, city.

# %%
run("SELECT country, state, city FROM offices")
# Out:
#      country       state           city
# 0        USA          CA  San Francisco
# 1        USA          MA         Boston
# 2        USA          NY            NYC
# 3     France        None          Paris
# 4      Japan  Chiyoda-Ku          Tokyo
# 5  Australia        None         Sydney
# 6         UK        None         London

# %% [markdown]
# ### 2. How many employees are there in the company?

# %%
run("SELECT COUNT(*) AS 'Total_Employees' FROM employees")
# Out:
#    Total_Employees
# 0               23

# %% [markdown]
# ### 3. What is the total of payments received?

# %%
run("SELECT SUM(amount) AS Total_Payments FROM payments")
# Out:
#    Total_Payments
# 0      8853839.23

# %%
run("SELECT * FROM productlines")
# Out:
#         productLine                                    textDescription  \
# 0      Classic Cars  Attention car enthusiasts: Make your wildest c...
# 1       Motorcycles  Our motorcycles are state of the art replicas ...
# 2            Planes  Unique, diecast airplane and helicopter replic...
# 3             Ships  The perfect holiday or anniversary gift for ex...
# 4            Trains  Model trains are a rewarding hobby for enthusi...
# 5  Trucks and Buses  The Truck and Bus models are realistic replica...
# 6      Vintage Cars  Our Vintage Car models realistically portray a...
#
#   htmlDescription image
# 0            None  None
# 1            None  None
# 2            None  None
# 3            None  None
# 4            None  None
# 5            None  None
# 6            None  None

# %% [markdown]
# ### 4. List the product lines that contain 'Cars'.

# %%
run("SELECT * FROM productlines WHERE productline LIKE '%Cars%'")
# Out:
#     productLine                                    textDescription  \
# 0  Classic Cars  Attention car enthusiasts: Make your wildest c...
# 1  Vintage Cars  Our Vintage Car models realistically portray a...
#
#   htmlDescription image
# 0            None  None
# 1            None  None

# %% [markdown]
# ### 5. Report total payments for October 28, 2004.

# %%
run("""
SELECT 
    DAY(paymentDate) AS Day,
    MONTH(paymentDate) AS Month,
    YEAR(paymentDate) AS Year,
    SUM(amount) AS 'Total Payments' 
FROM 
    payments 
WHERE 
    YEAR(paymentDate)=2004 AND MONTH(paymentDate)=10 AND DAY(paymentDate)=28
GROUP BY Day,Month,Year
""")
# Out:
#    Day  Month  Year  Total Payments
# 0   28     10  2004        47411.33

# %%
run("SELECT paymentDate, SUM(amount) AS totalPayments FROM payments WHERE paymentDate='2004-10-28'")
# Out:
#   paymentDate  totalPayments
# 0  2004-10-28       47411.33

# %% [markdown]
# ### 6. Report those payments greater than \$100,000.

# %%
run("SELECT * FROM payments WHERE amount > 100000")
# Out:
#    customerNumber checkNumber paymentDate     amount
# 0             124    AE215433  2005-03-05  101244.59
# 1             124    KI131716  2003-08-15  111654.40
# 2             141     ID10962  2004-12-31  116208.40
# 3             141    JE105477  2005-03-18  120166.58
# 4             148    KM172879  2003-12-26  105743.00

# %% [markdown]
# ### 7. List the products in each product line.

# %%
# all list productLine

run("""
    SELECT productCode, productLine, productName 
    FROM products
    ORDER BY productLine
""")
# Out:
#     productCode       productLine                                productName
# 0      S18_3482      Classic Cars                      1976 Ford Gran Torino
# 1      S24_2840      Classic Cars        1958 Chevy Corvette Limited Edition
# 2      S24_2887      Classic Cars                          1952 Citroen-15CV
# 3      S24_2972      Classic Cars                    1982 Lamborghini Diablo
# 4      S24_3191      Classic Cars                  1969 Chevrolet Camaro Z28
# 5      S18_2238      Classic Cars             1998 Chrysler Plymouth Prowler
# 6      S18_1984      Classic Cars                           1995 Honda Civic
# 7      S18_1889      Classic Cars                1948 Porsche 356-A Roadster
# 8      S24_3371      Classic Cars                  1971 Alpine Renault 1600s
# 9      S24_2766      Classic Cars                         1949 Jaguar XK 120
# 10     S18_2870      Classic Cars               1999 Indy 500 Monte Carlo SS
# ...

# %%
# Classic Cars

run("""
    SELECT productCode, productLine, productName 
    FROM products
    WHERE productLine = "Classic Cars"
""")
# Out:
#    productCode   productLine                          productName
# 0     S10_1949  Classic Cars             1952 Alpine Renault 1300
# 1     S10_4757  Classic Cars                  1972 Alfa Romeo GTA
# 2     S10_4962  Classic Cars               1962 LanciaA Delta 16V
# 3     S12_1099  Classic Cars                    1968 Ford Mustang
# 4     S12_1108  Classic Cars                    2001 Ferrari Enzo
# 5     S12_3148  Classic Cars                   1969 Corvair Monza
# 6     S12_3380  Classic Cars                   1968 Dodge Charger
# 7     S12_3891  Classic Cars                     1969 Ford Falcon
# 8     S12_3990  Classic Cars              1970 Plymouth Hemi Cuda
# 9     S12_4675  Classic Cars                   1969 Dodge Charger
# 10    S18_1129  Classic Cars                      1993 Mazda RX-7
# 11    S18_1589  Classic Cars                1965 Aston Martin DB5
# 12    S18_1889  Classic Cars          1948 Porsche 356-A Roadster
# ...

# %%
# Motorcycles

run("""
    SELECT productCode, productLine, productName 
    FROM products
    WHERE productLine = "Motorcycles"
""")
# Out:
#    productCode  productLine                            productName
# 0     S10_1678  Motorcycles  1969 Harley Davidson Ultimate Chopper
# 1     S10_2016  Motorcycles                  1996 Moto Guzzi 1100i
# 2     S10_4698  Motorcycles   2003 Harley-Davidson Eagle Drag Bike
# 3     S12_2823  Motorcycles                       2002 Suzuki XREO
# 4     S18_2625  Motorcycles    1936 Harley Davidson El Knucklehead
# 5     S18_3782  Motorcycles                       1957 Vespa GS150
# 6     S24_1578  Motorcycles                      1997 BMW R 1100 S
# 7     S24_2000  Motorcycles               1960 BSA Gold Star DBD34
# 8     S24_2360  Motorcycles                1982 Ducati 900 Monster
# 9     S32_1374  Motorcycles                       1997 BMW F650 ST
# 10    S32_2206  Motorcycles                      1982 Ducati 996 R
# 11    S32_4485  Motorcycles              1974 Ducati 350 Mk3 Desmo
# 12    S50_4713  Motorcycles                     2002 Yamaha YZR M1

# %%
# Planes

run("""
    SELECT productCode, productLine, productName 
    FROM products
    WHERE productLine = "Planes"
""")
# Out:
#    productCode productLine                       productName
# 0     S18_1662      Planes       1980s Black Hawk Helicopter
# 1     S18_2581      Planes                    P-51-D Mustang
# 2     S24_1785      Planes  1928 British Royal Navy Airplane
# 3     S24_2841      Planes            1900s Vintage Bi-Plane
# 4     S24_3949      Planes          Corsair F4U ( Bird Cage)
# 5     S24_4278      Planes           1900s Vintage Tri-Plane
# 6    S700_1691      Planes       American Airlines: B767-300
# 7    S700_2466      Planes    America West Airlines B757-200
# 8    S700_2834      Planes                     ATA: B757-300
# 9    S700_3167      Planes                F/A 18 Hornet 1/72
# 10   S700_4002      Planes         American Airlines: MD-11S
# 11    S72_1253      Planes                  Boeing X-32A JSF

# %%
# Ships

run("""
    SELECT productCode, productLine, productName 
    FROM products
    WHERE productLine = "Ships"
""")
# Out:
#   productCode productLine                productName
# 0    S18_3029       Ships     1999 Yamaha Speed Boat
# 1    S24_2011       Ships      18th century schooner
# 2   S700_1138       Ships      The Schooner Bluenose
# 3   S700_1938       Ships              The Mayflower
# 4   S700_2047       Ships                 HMS Bounty
# 5   S700_2610       Ships  The USS Constitution Ship
# 6   S700_3505       Ships                The Titanic
# 7   S700_3962       Ships             The Queen Mary
# 8    S72_3212       Ships                 Pont Yacht

# %%
# Trains

run("""
    SELECT productCode, productLine, productName 
    FROM products
    WHERE productLine = "Trains"
""")
# Out:
#   productCode productLine                             productName
# 0    S18_3259      Trains                Collectable Wooden Train
# 1    S32_3207      Trains  1950's Chicago Surface Lines Streetcar
# 2    S50_1514      Trains          1962 City of Detroit Streetcar

# %%
# Trucks and Buses

run("""
    SELECT productCode, productLine, productName 
    FROM products
    WHERE productLine = "Trucks and Buses"
""")
# Out:
#    productCode       productLine                                  productName
# 0     S12_1666  Trucks and Buses                               1958 Setra Bus
# 1     S12_4473  Trucks and Buses                            1957 Chevy Pickup
# 2     S18_1097  Trucks and Buses                       1940 Ford Pickup Truck
# 3     S18_2319  Trucks and Buses                       1964 Mercedes Tour Bus
# 4     S18_2432  Trucks and Buses                        1926 Ford Fire Engine
# 5     S18_4600  Trucks and Buses                             1940s Ford truck
# 6     S24_2300  Trucks and Buses                     1962 Volkswagen Microbus
# 7     S32_1268  Trucks and Buses                  1980’s GM Manhattan Express
# 8     S32_2509  Trucks and Buses                  1954 Greyhound Scenicruiser
# 9     S32_3522  Trucks and Buses  1996 Peterbilt 379 Stake Bed with Outrigger
# 10    S50_1392  Trucks and Buses             Diamond T620 Semi-Skirted Tanker

# %%
# Vintage Cars

run("""
    SELECT productCode, productLine, productName 
    FROM products
    WHERE productLine = "Vintage Cars"
""")
# Out:
#    productCode   productLine                                productName
# 0     S18_1342  Vintage Cars                       1937 Lincoln Berline
# 1     S18_1367  Vintage Cars   1936 Mercedes-Benz 500K Special Roadster
# 2     S18_1749  Vintage Cars                   1917 Grand Touring Sedan
# 3     S18_2248  Vintage Cars                         1911 Ford Town Car
# 4     S18_2325  Vintage Cars                  1932 Model A Ford J-Coupe
# 5     S18_2795  Vintage Cars                     1928 Mercedes-Benz SSK
# 6     S18_2949  Vintage Cars                1913 Ford Model T Speedster
# 7     S18_2957  Vintage Cars                         1934 Ford V8 Coupe
# 8     S18_3136  Vintage Cars        18th Century Vintage Horse Carriage
# 9     S18_3140  Vintage Cars                          1903 Ford Model A
# 10    S18_3320  Vintage Cars                   1917 Maxwell Touring Car
# 11    S18_3856  Vintage Cars    1941 Chevrolet Special Deluxe Cabriolet
# ...

# %% [markdown]
# ### 8. How many products in each product line?

# %%
run("SELECT productLine, COUNT(productName) AS Total_Products FROM products GROUP BY productLine")
# Out:
#         productLine  Total_Products
# 0      Classic Cars              38
# 1       Motorcycles              13
# 2            Planes              12
# 3             Ships               9
# 4            Trains               3
# 5  Trucks and Buses              11
# 6      Vintage Cars              24

# %% [markdown]
# ### 9. What is the minimum payment received?

# %%
run("SELECT Min(amount) as Minimum_Payment FROM payments")
# Out:
#    Minimum_Payment
# 0           615.45

# %% [markdown]
# ### 10. List all payments greater than twice the average payment.

# %%
run("""
SELECT *
FROM payments 
WHERE 
    amount>(SELECT AVG(amount) FROM payments)*2
""")
# Out:
#     customerNumber checkNumber paymentDate     amount
# 0              114    MA765515  2004-12-15   82261.22
# 1              124    AE215433  2005-03-05  101244.59
# 2              124    BG255406  2004-08-28   85410.87
# 3              124     ET64396  2005-04-16   83598.04
# 4              124    KI131716  2003-08-15  111654.40
# 5              141     ID10962  2004-12-31  116208.40
# 6              141    IN446258  2005-03-25   65071.26
# 7              141    JE105477  2005-03-18  120166.58
# 8              148    KM172879  2003-12-26  105743.00
# 9              167    GN228846  2003-12-03   85024.46
# 10             239    NQ865547  2004-03-15   80375.24
# 11             321     DJ15149  2003-11-03   85559.12
# 12             323    AL493079  2005-05-23   75020.13

# %%
run("(SELECT AVG(amount) FROM payments)")
# Out:
#     AVG(amount)
# 0  32431.645531

# %% [markdown]
# ### 11. What is the average percentage markup of the MSRP on buyPrice?

# %%
run("desc products")
# Out:
#                 Field           Type Null  Key Default Extra
# 0         productCode    varchar(15)   NO  PRI    None
# 1         productName    varchar(70)   NO         None
# 2         productLine    varchar(50)   NO  MUL    None
# 3        productScale    varchar(10)   NO         None
# 4       productVendor    varchar(50)   NO         None
# 5  productDescription           text   NO         None
# 6     quantityInStock    smallint(6)   NO         None
# 7            buyPrice  decimal(10,2)   NO         None
# 8                MSRP  decimal(10,2)   NO         None

# %%
run("SELECT AVG((MSRP-buyPrice) / buyPrice*100) as average_Percentage_Markup FROM products")
# Out:
#    average_Percentage_Markup
# 0                  88.702392

# %% [markdown]
# ### 12. How many distinct products does ClassicModels sell?

# %%
run("SELECT COUNT(DISTINCT productName) AS Total_Products FROM products")
# Out:
#    Total_Products
# 0             110

# %%
run("SELECT DISTINCT productName AS Products FROM products")
# Out:
#                                         Products
# 0          1969 Harley Davidson Ultimate Chopper
# 1                       1952 Alpine Renault 1300
# 2                          1996 Moto Guzzi 1100i
# 3           2003 Harley-Davidson Eagle Drag Bike
# 4                            1972 Alfa Romeo GTA
# 5                         1962 LanciaA Delta 16V
# 6                              1968 Ford Mustang
# 7                              2001 Ferrari Enzo
# 8                                 1958 Setra Bus
# 9                               2002 Suzuki XREO
# 10                            1969 Corvair Monza
# 11                            1968 Dodge Charger
# 12                              1969 Ford Falcon
# 13                       1970 Plymouth Hemi Cuda
# 14                             1957 Chevy Pickup
# 15                            1969 Dodge Charger
# 16                        1940 Ford Pickup Truck
# 17                               1993 Mazda RX-7
# ...

# %% [markdown]
# ### 13. Report the name and city of customers who don't have sales representatives?

# %%
run("SELECT customerName, city FROM customers WHERE salesRepEmployeeNumber IS NOT NULL")
# Out:
#                           customerName           city
# 0                    Atelier graphique         Nantes
# 1                   Signal Gift Stores      Las Vegas
# 2           Australian Collectors, Co.      Melbourne
# 3                    La Rochelle Gifts         Nantes
# 4                   Baane Mini Imports        Stavern
# 5         Mini Gifts Distributors Ltd.     San Rafael
# 6                 Blauer See Auto, Co.      Frankfurt
# 7                      Mini Wheels Co.  San Francisco
# 8                    Land of Toys Inc.            NYC
# 9               Euro+ Shopping Channel         Madrid
# 10            Volvo Model Replicas, Co          Luleå
# 11            Danish Wholesale Imports      Kobenhavn
# 12              Saveley & Henriot, Co.           Lyon
# 13             Dragon Souveniers, Ltd.      Singapore
# 14                  Muscle Machine Inc            NYC
# 15               Diecast Classics Inc.      Allentown
# ...

# %% [markdown]
# ### 14. What are the names of executives with VP or Manager in their title? Use the CONCAT function to combine the employee's first name and last name into a single field for reporting.

# %%
run("""
SELECT 
    CONCAT(firstName, ' ', lastName) 
    AS fullName, jobTitle
FROM employees 
WHERE 
    jobTitle LIKE '%VP%' OR jobTitle LIKE '%Manager%'
""")
# Out:
#             fullName              jobTitle
# 0     Mary Patterson              VP Sales
# 1      Jeff Firrelli          VP Marketing
# 2  William Patterson  Sales Manager (APAC)
# 3      Gerard Bondur   Sale Manager (EMEA)
# 4        Anthony Bow    Sales Manager (NA)

# %% [markdown]
# ### 15. Which orders have a value greater than $5,000?

# %%
run("""
    SELECT
    orderNumber,sum(priceEach * quantityOrdered) as TotalValue
    FROM orderdetails
    group by orderNumber
    having TotalValue > 5000
    """)
# Out:
#      orderNumber  TotalValue
# 0          10100    10223.83
# 1          10101    10549.01
# 2          10102     5494.78
# 3          10103    50218.95
# 4          10104    40206.20
# 5          10105    53959.21
# 6          10106    52151.81
# 7          10107    22292.62
# 8          10108    51001.22
# 9          10109    25833.14
# 10         10110    48425.69
# 11         10111    16537.85
# 12         10112     7674.94
# 13         10113    11044.30
# 14         10114    33383.14
# 15         10115    21665.98
# 16         10117    44380.15
# 17         10119    35826.33
# 18         10120    45864.03
# 19         10121    16700.47
# 20         10122    50824.66
# 21         10123    14571.44
# 22         10124    32641.98
# 23         10125     7565.08
# 24         10126    57131.92
# 25         10127    58841.35
# 26         10128    13884.99
# 27         10129    29429.14
# 28         10130     6036.96
# 29         10131    17032.29
# ..           ...         ...
# ...
