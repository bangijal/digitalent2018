# %% [markdown]
# ![title](img/python2.png)

# %% [markdown]
# # == Projects ==
#
# Nama : Rizal Imran Rusyadi (BigData-B)

# %% [markdown]
# # 1. Deskripsi Data

# %% [markdown]
# Dataset ini berisi mengenai jumlah rumah sakit dan tempat tidur di rumah sakit berdasarkan kelas rumah sakit per provinsi
#
# Penjelasan mengenai Variabel pada Dataset ini:
#
# 1. kode_provinsi: Kode Provinsi
# 2. nama_provinsi: Nama Provinsi
# 3. kelas_rumah_sakit: Kelas Rumah Sakit
# 4. jumlah_rumah_sakit: Jumlah Rumah Sakit
# 5. jumlah_tempat_tidur: Jumlah Tempat Tidur
#
# Catatan:
#
# Data bersumber dari Ditjen Bina Upaya Kesehatan, Kemenkes RI, 2013
# Rumah Sakit yang dimaksud adalah rumah sakit yang telah memiliki kode RS
#
# sumber data : https://data.go.id/dataset/rumah-sakit-dan-tempat-tidur-di-rumah-sakit-berdasarkan-kelas-rumah-sakit

# %% [markdown]
# == Rumah Sakit dan Tempat Tidur di Rumah Sakit berdasarkan kelas Rumah Sakit, data dalam bentuk format .csv yang dibaca dengan menggunakan modul python : pandas
#
# cekidot :D

# %%
# Melakukan import file .csv

import pandas as pd
data_rumkit = pd.read_csv('processed-jumlah-rs-tempat-tidur-kelas-rs-per-2012.csv', delimiter = ',', encoding = "ISO-8859-1")

# %% [markdown]
# # Menampilkan Data Rumah Sakit (All)

# %%
#  Load jumlah rumah sakit dan tempat tidur di rumah sakit berdasarkan kelas rumah sakit per provinsi

data_rumkit
# Out:
#      kode_provinsi                   nama_provinsi       kelas_rumah_sakit  \
# 0               11  Prov. Nanggroe Aceh Darussalam                 Kelas A
# 1               11  Prov. Nanggroe Aceh Darussalam                 Kelas B
# 2               11  Prov. Nanggroe Aceh Darussalam                 Kelas C
# 3               11  Prov. Nanggroe Aceh Darussalam                 Kelas D
# 4               11  Prov. Nanggroe Aceh Darussalam  Belum Ditetapkan Kelas
# 5               12            Prov. Sumatera Utara                 Kelas A
# 6               12            Prov. Sumatera Utara                 Kelas B
# 7               12            Prov. Sumatera Utara                 Kelas C
# 8               12            Prov. Sumatera Utara                 Kelas D
# 9               12            Prov. Sumatera Utara  Belum Ditetapkan Kelas
# 10              13            Prov. Sumatera Barat                 Kelas A
# ...

# %% [markdown]
# # Menampilkan Kode dan Nama Provinsi

# %%
# Load kode dan nama provinsi

data_rumkit[['kode_provinsi','nama_provinsi']]
# Out:
#      kode_provinsi                   nama_provinsi
# 0               11  Prov. Nanggroe Aceh Darussalam
# 1               11  Prov. Nanggroe Aceh Darussalam
# 2               11  Prov. Nanggroe Aceh Darussalam
# 3               11  Prov. Nanggroe Aceh Darussalam
# 4               11  Prov. Nanggroe Aceh Darussalam
# 5               12            Prov. Sumatera Utara
# 6               12            Prov. Sumatera Utara
# 7               12            Prov. Sumatera Utara
# 8               12            Prov. Sumatera Utara
# 9               12            Prov. Sumatera Utara
# 10              13            Prov. Sumatera Barat
# 11              13            Prov. Sumatera Barat
# 12              13            Prov. Sumatera Barat
# 13              13            Prov. Sumatera Barat
# 14              13            Prov. Sumatera Barat
# 15              14                      Prov. Riau
# 16              14                      Prov. Riau
# ...

# %% [markdown]
# # Data daftar rumah sakit yang belum ditetapkan kelas

# %%
# Load data daftar rumah sakit yang belum ditetapkan kelas

data_rumkit[data_rumkit['kelas_rumah_sakit']=='Belum Ditetapkan Kelas']
# Out:
#      kode_provinsi                    nama_provinsi       kelas_rumah_sakit  \
# 4               11   Prov. Nanggroe Aceh Darussalam  Belum Ditetapkan Kelas
# 9               12             Prov. Sumatera Utara  Belum Ditetapkan Kelas
# 14              13             Prov. Sumatera Barat  Belum Ditetapkan Kelas
# 19              14                       Prov. Riau  Belum Ditetapkan Kelas
# 24              15                      Prov. Jambi  Belum Ditetapkan Kelas
# 29              16           Prov. Sumatera Selatan  Belum Ditetapkan Kelas
# 34              17                   Prov. Bengkulu  Belum Ditetapkan Kelas
# 39              18                    Prov. Lampung  Belum Ditetapkan Kelas
# 44              19  Prov. Kepulauan Bangka Belitung  Belum Ditetapkan Kelas
# 49              21             Prov. Kepulauan Riau  Belum Ditetapkan Kelas
# 54              31                Prov. DKI Jakarta  Belum Ditetapkan Kelas
# ...

# %%
# Load jumlah rs yang belum ditetapkan kelas

print("Jumlah daftar rumah sakit Belum Ditetapkan Kelas  : ",len(data_rumkit[data_rumkit['kelas_rumah_sakit']=='Belum Ditetapkan Kelas']))
# Out:
# Jumlah daftar rumah sakit Belum Ditetapkan Kelas  :  33

# %% [markdown]
# # Data daftar rumah sakit KELAS A

# %%
# Load data daftar rumah sakit kelas A 

data_rumkit[data_rumkit['kelas_rumah_sakit']=='Kelas A']
# Out:
#      kode_provinsi                    nama_provinsi kelas_rumah_sakit  \
# 0               11   Prov. Nanggroe Aceh Darussalam           Kelas A
# 5               12             Prov. Sumatera Utara           Kelas A
# 10              13             Prov. Sumatera Barat           Kelas A
# 15              14                       Prov. Riau           Kelas A
# 20              15                      Prov. Jambi           Kelas A
# 25              16           Prov. Sumatera Selatan           Kelas A
# 30              17                   Prov. Bengkulu           Kelas A
# 35              18                    Prov. Lampung           Kelas A
# 40              19  Prov. Kepulauan Bangka Belitung           Kelas A
# 45              21             Prov. Kepulauan Riau           Kelas A
# 50              31                Prov. DKI Jakarta           Kelas A
# 55              32                 Prov. Jawa Barat           Kelas A
# ...

# %%
# Load jumlah rs kelas A

print("Jumlah daftar rumah sakit kelas A ada : ",len(data_rumkit[data_rumkit['kelas_rumah_sakit']=='Kelas A']))
# Out:
# Jumlah daftar rumah sakit kelas A ada :  33

# %% [markdown]
# # Data daftar rumah sakit KELAS B

# %%
# Load data daftar rumah sakit kelas B 

data_rumkit[data_rumkit['kelas_rumah_sakit']=='Kelas B']
# Out:
#      kode_provinsi                    nama_provinsi kelas_rumah_sakit  \
# 1               11   Prov. Nanggroe Aceh Darussalam           Kelas B
# 6               12             Prov. Sumatera Utara           Kelas B
# 11              13             Prov. Sumatera Barat           Kelas B
# 16              14                       Prov. Riau           Kelas B
# 21              15                      Prov. Jambi           Kelas B
# 26              16           Prov. Sumatera Selatan           Kelas B
# 31              17                   Prov. Bengkulu           Kelas B
# 36              18                    Prov. Lampung           Kelas B
# 41              19  Prov. Kepulauan Bangka Belitung           Kelas B
# 46              21             Prov. Kepulauan Riau           Kelas B
# 51              31                Prov. DKI Jakarta           Kelas B
# 56              32                 Prov. Jawa Barat           Kelas B
# ...

# %%
# Load jumlah rs kelas B

print("Jumlah daftar rumah sakit kelas B ada : ",len(data_rumkit[data_rumkit['kelas_rumah_sakit']=='Kelas B']))
# Out:
# Jumlah daftar rumah sakit kelas B ada :  33

# %% [markdown]
# # Data daftar rumah sakit KELAS C

# %%
# Load data daftar rumah sakit kelas c 

data_rumkit[data_rumkit['kelas_rumah_sakit']=='Kelas C']
# Out:
#      kode_provinsi                    nama_provinsi kelas_rumah_sakit  \
# 2               11   Prov. Nanggroe Aceh Darussalam           Kelas C
# 7               12             Prov. Sumatera Utara           Kelas C
# 12              13             Prov. Sumatera Barat           Kelas C
# 17              14                       Prov. Riau           Kelas C
# 22              15                      Prov. Jambi           Kelas C
# 27              16           Prov. Sumatera Selatan           Kelas C
# 32              17                   Prov. Bengkulu           Kelas C
# 37              18                    Prov. Lampung           Kelas C
# 42              19  Prov. Kepulauan Bangka Belitung           Kelas C
# 47              21             Prov. Kepulauan Riau           Kelas C
# 52              31                Prov. DKI Jakarta           Kelas C
# 57              32                 Prov. Jawa Barat           Kelas C
# ...

# %%
# Load jumlah rs kelas C

print("Jumlah daftar rumah sakit kelas C ada : ",len(data_rumkit[data_rumkit['kelas_rumah_sakit']=='Kelas C']))
# Out:
# Jumlah daftar rumah sakit kelas C ada :  33

# %% [markdown]
# # # Data daftar rumah sakit KELAS D

# %%
# Load data daftar rumah sakit kelas D 

data_rumkit[data_rumkit['kelas_rumah_sakit']=='Kelas D']
# Out:
#      kode_provinsi                    nama_provinsi kelas_rumah_sakit  \
# 3               11   Prov. Nanggroe Aceh Darussalam           Kelas D
# 8               12             Prov. Sumatera Utara           Kelas D
# 13              13             Prov. Sumatera Barat           Kelas D
# 18              14                       Prov. Riau           Kelas D
# 23              15                      Prov. Jambi           Kelas D
# 28              16           Prov. Sumatera Selatan           Kelas D
# 33              17                   Prov. Bengkulu           Kelas D
# 38              18                    Prov. Lampung           Kelas D
# 43              19  Prov. Kepulauan Bangka Belitung           Kelas D
# 48              21             Prov. Kepulauan Riau           Kelas D
# 53              31                Prov. DKI Jakarta           Kelas D
# 58              32                 Prov. Jawa Barat           Kelas D
# ...

# %%
# Load jumlah daftar rs kelas D

print("Jumlah daftar rumah sakit kelas D ada : ",len(data_rumkit[data_rumkit['kelas_rumah_sakit']=='Kelas D']))
# Out:
# Jumlah daftar rumah sakit kelas D ada :  33

# %% [markdown]
# # 2. Statistik tentang data rumah sakit

# %%
# Total rumah sakit keseluruhan (kelas A,B,C,D dan belum ditetapkan kelas)

s = data_rumkit.jumlah_rumah_sakit.sum()

print('Total rumah sakit ada :',s)
# Out:
# Total rumah sakit ada : 2083

# %%
# Total tempat tidur keseluruhan (kelas A,B,C,D dan belum ditetapkan kelas)

stt = data_rumkit.jumlah_tempat_tidur.sum()

print('Total jumlah tempat tidur ada :', stt)
# Out:
# Total jumlah tempat tidur ada : 231432

# %%
# Total jumlah rumah sakit bernilai paling sedikit

mi = data_rumkit.jumlah_rumah_sakit.min()
print(mi)
# Out:
# 0

# %%
# load data daftar rumah sakit yang berjumlah nol 

data_rumkit[data_rumkit['jumlah_rumah_sakit'] == 0]
# Out:
#      kode_provinsi                    nama_provinsi kelas_rumah_sakit  \
# 30              17                   Prov. Bengkulu           Kelas A
# 40              19  Prov. Kepulauan Bangka Belitung           Kelas A
# 45              21             Prov. Kepulauan Riau           Kelas A
# 85              52        Prov. Nusa Tenggara Barat           Kelas A
# 90              53        Prov. Nusa Tenggara Timur           Kelas A
# 95              61           Prov. Kalimantan Barat           Kelas A
# 100             62          Prov. Kalimantan Tengah           Kelas A
# 120             72            Prov. Sulawesi Tengah           Kelas A
# 130             74          Prov. Sulawesi Tenggara           Kelas A
# 135             75                  Prov. Gorontalo           Kelas A
# 140             76             Prov. Sulawesi Barat           Kelas A
# 141             76             Prov. Sulawesi Barat           Kelas B
# ...

# %%
# Total jumlah rumah sakit paling sedikit banyak

ma = data_rumkit.jumlah_rumah_sakit.max()
print('Total Jumlah rumah sakit paling banyak :',ma)
# Out:
# Total Jumlah rumah sakit paling banyak : 102

# %%
# load data daftar rumah sakit yang berjumlah 102 

data_rumkit[data_rumkit['jumlah_rumah_sakit'] == 102]
# Out:
#     kode_provinsi     nama_provinsi       kelas_rumah_sakit  \
# 74             35  Prov. Jawa Timur  Belum Ditetapkan Kelas
#
#     jumlah_rumah_sakit  jumlah_tempat_tidur
# 74                 102                 6428

# %%
# Total jumlah tempat tidur paling sedikit

mi = data_rumkit.jumlah_tempat_tidur.min()
print('Total Jumlah tempat tidur paling sedikit :',mi)
# Out:
# Total Jumlah tempat tidur paling sedikit : 0

# %%
# load data daftar tempat tidur yang berjumlah nol 

data_rumkit[data_rumkit['jumlah_tempat_tidur'] == 0]
# Out:
#      kode_provinsi                    nama_provinsi kelas_rumah_sakit  \
# 30              17                   Prov. Bengkulu           Kelas A
# 40              19  Prov. Kepulauan Bangka Belitung           Kelas A
# 45              21             Prov. Kepulauan Riau           Kelas A
# 85              52        Prov. Nusa Tenggara Barat           Kelas A
# 90              53        Prov. Nusa Tenggara Timur           Kelas A
# 95              61           Prov. Kalimantan Barat           Kelas A
# 100             62          Prov. Kalimantan Tengah           Kelas A
# 120             72            Prov. Sulawesi Tengah           Kelas A
# 130             74          Prov. Sulawesi Tenggara           Kelas A
# 135             75                  Prov. Gorontalo           Kelas A
# 140             76             Prov. Sulawesi Barat           Kelas A
# 141             76             Prov. Sulawesi Barat           Kelas B
# ...

# %%
# jumlah tempat tidur paling banyak

ma = data_rumkit.jumlah_tempat_tidur.max()
print('Jumlah tempat tidur paling banyak :',ma)
# Out:
# Jumlah tempat tidur paling banyak : 11104

# %%
# load data daftar tempat tidur yang berjumlah 11104 

data_rumkit[data_rumkit['jumlah_tempat_tidur'] == 11104]
# Out:
#     kode_provinsi      nama_provinsi kelas_rumah_sakit  jumlah_rumah_sakit  \
# 62             33  Prov. Jawa Tengah           Kelas C                  94
#
#     jumlah_tempat_tidur
# 62                11104

# %%
# Mean dari jumlah rumah sakit

me = data_rumkit.jumlah_rumah_sakit.mean()
print('Hasil (mean) :',me)
# Out:
# Hasil (mean) : 12.624242424242425

# %%
# Median dari jumlah rumah sakit
md = data_rumkit.jumlah_rumah_sakit.median()
print('Hasil (median) :',md)
# Out:
# Hasil (median) : 6.0

# %% [markdown]
# # 3. Visualisasi Sederhana

# %% [markdown]
# # a. Visualisasi Jumlah Rumah Sakit per Provinsi

# %%
ax = data_rumkit.groupby('nama_provinsi').max()['jumlah_rumah_sakit']
ax = ax.plot(kind='bar', title ="JUMLAH RUMAH SAKIT per PROVINSI ", figsize=(20,6), legend=True, fontsize=12)
ax.set_xlabel("Nama Provinsi", fontsize=12)
ax.set_ylabel("Jumlah Rumah Sakit", fontsize=12)
# Out:
# Text(0,0.5,'Jumlah Rumah Sakit')

# %%
data_rumkit.groupby('jumlah_rumah_sakit').max()
# Out:
#                     kode_provinsi             nama_provinsi  \
# jumlah_rumah_sakit
# 0                              94   Prov. Sulawesi Tenggara
# 1                              94      Prov. Sumatera Barat
# 2                              81    Prov. Sulawesi Selatan
# 3                              82      Prov. Sumatera Utara
# 4                              91      Prov. Sumatera Barat
# 5                              91    Prov. Sumatera Selatan
# 6                              73    Prov. Sulawesi Selatan
# 7                              74   Prov. Sulawesi Tenggara
# 8                              81      Prov. Sulawesi Utara
# 9                              94    Prov. Sumatera Selatan
# 10                             71      Prov. Sulawesi Utara
# 11                             94     Prov. Sulawesi Tengah
# 12                             63  Prov. Kalimantan Selatan
# 13                             94      Prov. Sumatera Utara
# ...

# %% [markdown]
# # b. Visualisasi Jumlah Tempat Tidur per Provinsi

# %%
ax = data_rumkit.groupby('nama_provinsi')['jumlah_tempat_tidur'].max()
ax = ax.plot(kind='bar', title ="JUMLAH TEMPAT TIDUR PER-PROVINSI", figsize=(20,5), legend=True, fontsize=12)
ax.set_xlabel("Nama Provinsi", fontsize=12)
ax.set_ylabel("Jumlah Tempat Tidur", fontsize=12)
# Out:
# Text(0,0.5,'Jumlah Tempat Tidur')

# %%
data_rumkit.groupby('jumlah_tempat_tidur').max()
# Out:
#                      kode_provinsi                    nama_provinsi  \
# jumlah_tempat_tidur
# 0                               94          Prov. Sulawesi Tenggara
# 46                              18                    Prov. Lampung
# 60                              63         Prov. Kalimantan Selatan
# 61                              62          Prov. Kalimantan Tengah
# 62                              19  Prov. Kepulauan Bangka Belitung
# 81                              82               Prov. Maluku Utara
# 90                              75                  Prov. Gorontalo
# 120                             19  Prov. Kepulauan Bangka Belitung
# 129                             75                  Prov. Gorontalo
# 140                             21             Prov. Kepulauan Riau
# 149                             15                      Prov. Jambi
# 160                             82               Prov. Maluku Utara
# ...

# %% [markdown]
# # 3. Visualisasi Jumlah berdasarkan Kelas

# %%
ax = data_rumkit.groupby('kelas_rumah_sakit')['jumlah_rumah_sakit'].mean()
ax = ax.plot(kind='pie', title ="JUMLAH KELAS ", figsize=(11,11), legend=True, fontsize=12)

# %% [markdown]
# ![title](img/python2.png)

# %%
data_rumkit.groupby('kelas_rumah_sakit').mean()
# Out:
#                         kode_provinsi  jumlah_rumah_sakit  jumlah_tempat_tidur
# kelas_rumah_sakit
# Belum Ditetapkan Kelas      47.030303           22.030303          1519.303030
# Kelas A                     47.030303            1.696970           614.606061
# Kelas B                     47.030303            7.727273          1918.090909
# Kelas C                     47.030303           19.090909          2208.484848
# Kelas D                     47.030303           12.575758           752.606061

# %% [markdown]
# # 4. Narasi Analisis

# %% [markdown]
# Berdasarkan dataset yang telah diolah dengan metode matematis dan divisualisasikan, bisa diambil kesimpulan yaitu pada (a)Jumlah Rumah Sakit per Provinsi : jumlah terbanyak rumah sakit terdapat pada Provinsi Timur yang berjumlah 102 rumah sakit dan belum ditetapkan kelas. Sehingga kita bisa mengetahui bahwa sejumlah kelas RS yang berada di Prov Jawa Timur perlu dikelompokan kembali untuk pembagian kelas secara merata, agar calon pasien dapat dirawat sesuai hak dan kemampuannya.
#
# (b)Jumlah Tempat Tidur per Provinsi : jumlah terbanyak dimiliki oleh provinsi Jawa Tengah yaitu 11.104 tempat tidur yang berada di kelas C, sedangkan rumah sakit yang tersebar di Provinsi Jawa Tengah sejumlah 94. Sehingga informasi yang menarik pada poin ini yaitu menandakan jumlah rumah sakit kelas C yang berada di Jawa Tengah memiliki kuota terbanyak dari semua provinsi yang terdaftar.
#
# (c)Jumlah Berdasarkan Kelas, ini maksudnya yaitu setiap masing - masing rumah sakit memiliki kelas yang terdiri dari A,B,C,D dan yang belum ditetapkan masuk kelas mana. Dari data perhitungan rata-rata pada poin (c)Visualisasi ini, informasi yang didapatkan : untuk RS kelas A memilik jumlah yang paling sedikit dan yang terbanyak yaitu RS yang belum ditetapkan kelas. Untuk itu perlu dikaji untuk re-classification dalam penentuan kelas khususnya untuk kategori belum ditetapkan kelas.
#
# === Keterangan Rumah Sakit Kelas A, B, C ,D ===
# ----------------------------------
# Rumah Sakit Tipe / Kelas A
# -------
# Rumah Sakit Kelas A adalah rumah sakit yang mampu memberikan pelayanan kedokteran spesialis dan subspesialis luas oleh pemerintah, rumah sakit ini telah ditetapkan sebagai tempat pelayanan rujukan tertinggi (top referral hospital) atau disebut juga rumah sakit pusat.
# Kita mengenal pelayanan BPJS menggunakan sistem berjenjang, ika tidak bisa ditangai di faskes tk1 (puskesmas, poliklinik, doktr pribadi) maka akan dirujuk ke fasks tk 2 (rumah sakit kabupaten), jika di faskes tingkat 2 masih belum juga bisa ditangani maka pasien akan di rujukan ke faskes tinggal 3 yaitu rumah sakit tipe A.
#
# Rumah Sakit Tipe / Kelas B
# ------
# Rumah sakit Tipe B adalah rumah sakit yang mampu memberikan pelayanan kedokteran medik spesialis luas dan subspesialis terbatas.
# Rumah sakit tipe B ini direncanakan akan didirikan di setiap ibukota propinsi (provincial hospital) yang dapat menampung pelayanan rujukan dari rumah sakit kabupaten. Rumah sakit pendidikan yang tidak termasuk tipe A juga diklasifikasikan sebagai rumah sakit tipe B.
#
#
# Rumah Sakit Tipe / Kelas C
# ---
# Rumah Sakit Kelas C adalah rumah sakit yang mampu memberikan pelayanan kedokteran subspesialis terbatas. Terdapat empat macam pelayanan spesialis disediakan yakni pelayanan penyakit dalam, pelayanan bedah, pelayanan kesehatan anak, serta pelayanan kebidanan dan kandungan.
# Rumah sakit kelas C ini adalah rumah sakit yang didirikan di Kota atau kabupaten-kapupaten sebagai faskes tingkat 2 yang menampung rujukan dari faskes tingkat 1 (puskesmas/poliklinik atau dokter pribadi).
#
#
# Rumah Sakit Tipe / Kelas D
# ----
# Rumah Sakit Kelas D adalah rumah Sakit ini bersifat transisi karena pada suatu saat akan ditingkatkan menjadi rumah sakit kelas C.
# Pada saat ini kemampuan rumah sakit tipe D hanyalah memberikan pelayanan kedokteran umum dan kedokteran gigi. Sama halnya dengan rumah sakit tipe C, rumah sakit tipe D juga menampung pelayanan yang berasal dari puskesmas
