# %% [markdown]
# # One to many relationship

# %%
import pymysql
import pandas as pd

host = '127.0.0.1'
port = "3306"
user = 'root'
password = ''
database = 'classicmodels'

conn = pymysql.connect(
    host=host,
    port=int(port),
    user=user,
    passwd=password,
    db=database,
    charset='utf8mb4')

def run(sql):
    df = pd.read_sql_query(sql,conn)
    return df

# %% [markdown]
# ### 1. Report the account representative for each customer.

# %%
run("""
SELECT 
    customerNumber, 
    customerName, 
    employeeNumber,
    salesRepEmployeeNumber    
FROM
    customers t1
        INNER JOIN
    employees t2 ON t1.salesRepEmployeeNumber = t2.employeeNumber
""")
# Out:
#     customerNumber                       customerName  employeeNumber  \
# 0              148            Dragon Souveniers, Ltd.            1621
# 1              177               Osaka Souveniers Co.            1621
# 2              211        King Kong Collectables, Co.            1621
# 3              385                    Cruz & Sons Co.            1621
# 4              398            Tokyo Collectables, Ltd            1621
# 5              114         Australian Collectors, Co.            1611
# 6              276            Anna's Decorations, Ltd            1611
# 7              282          Souveniers And Things Co.            1611
# 8              333        Australian Gift Network, Co            1611
# 9              471       Australian Collectables, Ltd            1611
# 10             166                   Handji Gifts& Co            1612
# 11             323         Down Under Souveniers, Inc            1612
# 12             357                    GiftsForHim.com            1612
# 13             412      Extreme Desk Decorations, Ltd            1612
# 14             496                  Kelly's Gift Shop            1612
# 15             146             Saveley & Henriot, Co.            1337
# 16             172          La Corne D'abondance, Co.            1337
# 17             250                    Lyon Souveniers            1337
# 18             350               Marseille Mini Autos            1337
# 19             353                 Reims Collectables            1337
# 20             406                  Auto Canal+ Petit            1337
# 21             103                  Atelier graphique            1370
# 22             119                  La Rochelle Gifts            1370
# 23             141             Euro+ Shopping Channel            1370
# 24             171           Daedalus Designs Imports            1370
# 25             209                        Mini Caravy            1370
# 26             242                       Alpha Cognac            1370
# 27             256               Auto Associés & Cie.            1370
# 28             145           Danish Wholesale Imports            1401
# 29             227               Heintze Collectables            1401
# ..             ...                                ...             ...
# 70             239       Collectable Mini Designs Co.            1166
# 71             347         Men 'R' US Retailers, Ltd.            1166
# 72             475        West Coast Collectables Co.            1166
# 73             173         Cambridge Collectables Co.            1188
# 74             204           Online Mini Collectables            1188
# 75             320                Mini Creations Ltd.            1188
# 76             339            Classic Gift Ideas, Inc            1188
# 77             379         Collectables For Less Inc.            1188
# 78             495               Diecast Collectables            1188
# 79             157              Diecast Classics Inc.            1216
# 80             198            Auto-Moto Classics Inc.            1216
# 81             286               Marta's Replicas Co.            1216
# 82             362                  Gifts4AllAges.com            1216
# 83             363       Online Diecast Creations Co.            1216
# 84             462                   FunGiftIdeas.com            1216
# 85             151                 Muscle Machine Inc            1286
# 86             168             American Souvenirs Inc            1286
# 87             181                    Vitachrome Inc.            1286
# 88             233       Québec Home Shopping Network            1286
# 89             424               Classic Legends Inc.            1286
# 90             455                   Super Scale Inc.            1286
# 91             456                    Microscale Inc.            1286
# 92             131                  Land of Toys Inc.            1323
# 93             175                    Gift Depot Inc.            1323
# 94             202     Canadian Gift Exchange Network            1323
# 95             260  Royal Canadian Collectables, Ltd.            1323
# 96             319                      Mini Classics            1323
# 97             328            Tekni Collectables Inc.            1323
# 98             447                   Gift Ideas Corp.            1323
# 99             486       Motor Mint Distributors Inc.            1323
#
#     salesRepEmployeeNumber
# 0                     1621
# 1                     1621
# 2                     1621
# 3                     1621
# 4                     1621
# 5                     1611
# 6                     1611
# 7                     1611
# 8                     1611
# 9                     1611
# 10                    1612
# 11                    1612
# 12                    1612
# 13                    1612
# 14                    1612
# 15                    1337
# 16                    1337
# 17                    1337
# 18                    1337
# 19                    1337
# 20                    1337
# 21                    1370
# 22                    1370
# 23                    1370
# 24                    1370
# 25                    1370
# 26                    1370
# 27                    1370
# 28                    1401
# 29                    1401
# ..                     ...
# 70                    1166
# 71                    1166
# 72                    1166
# 73                    1188
# 74                    1188
# 75                    1188
# 76                    1188
# 77                    1188
# 78                    1188
# 79                    1216
# 80                    1216
# 81                    1216
# 82                    1216
# 83                    1216
# 84                    1216
# 85                    1286
# 86                    1286
# 87                    1286
# 88                    1286
# 89                    1286
# 90                    1286
# 91                    1286
# 92                    1323
# 93                    1323
# 94                    1323
# 95                    1323
# 96                    1323
# 97                    1323
# 98                    1323
# 99                    1323
#
# [100 rows x 4 columns]

# %% [markdown]
# ### 2. Report total payments for Atelier graphique.
